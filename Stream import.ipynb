# %%
import os
import sys
import numpy as np
import errno
import glob
import pandas as pd

# %%
#!conda install --yes --prefix {sys.prefix} pandas

# %%
os.chdir('/home/brainhacker/Desktop/')
#os.chdir('/run/user/1000/gvfs/smb-share:server=192.168.1.2,share=brainhack/shared')

# %%
#a=np.loadtxt('Brainhack_stream2.txt')
a=pd.read_csv('Brainhack_stream2.txt',skiprows=5,sep='\t')
#a=pd.read_table('Brainhack_stream2.txt',skiprows=5,)

# %%
print(a)
# Out:
#           # Date          Time  Polaris Frame Number Calibration/Tracker Name  \
# 0     2019-03-22  14:09:34.911                 20602                   CB1175
# 1     2019-03-22  14:09:34.911                 20602                    CT677
# 2     2019-03-22  14:09:34.911                 20602                   LCT371
# 3     2019-03-22  14:09:34.911                 20602                    P1381
# 4     2019-03-22  14:09:34.911                 20602                   ST1089
# 5     2019-03-22  14:09:34.911                 20602               70mm alpha
# 6     2019-03-22  14:09:34.979                 20605                   CB1175
# 7     2019-03-22  14:09:34.979                 20605                    CT677
# 8     2019-03-22  14:09:34.979                 20605                   LCT371
# 9     2019-03-22  14:09:34.979                 20605                    P1381
# 10    2019-03-22  14:09:34.979                 20605                   ST1089
# ...

# %%
#stream=open('/run/user/1000/gvfs/smb-share:server=192.168.1.2,share=brainhack/shared/stream_PKbrain.txt')

# %%
#pd.DataFrame.as_matrix()

# %%
a1=a[['x','y','z']]

# %%
print(a1)
# Out:
#             x        y          z
# 0      (null)   (null)     (null)
# 1      (null)   (null)     (null)
# 2      66.969  340.446  -1011.192
# 3      (null)   (null)     (null)
# 4     256.751  157.279   -910.382
# 5     167.415  129.342    122.682
# 6      (null)   (null)     (null)
# 7      (null)   (null)     (null)
# 8      67.175  340.365  -1011.243
# 9      (null)   (null)     (null)
# 10    256.762  157.278   -910.391
# 11    167.198  129.346    122.655
# 12     (null)   (null)     (null)
# 13     (null)   (null)     (null)
# 14     67.207  340.232  -1011.281
# 15     (null)   (null)     (null)
# 16    256.759  157.278   -910.378
# 17    167.094  129.421    122.669
# 18     (null)   (null)     (null)
# 19     (null)   (null)     (null)
# 20     67.280  340.143  -1011.297
# 21     (null)   (null)     (null)
# 22    256.759  157.278   -910.378
# 23    166.929  129.405    122.713
# 24     (null)   (null)     (null)
# 25     (null)   (null)     (null)
# ...
